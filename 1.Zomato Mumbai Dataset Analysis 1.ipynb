# %% [markdown]
# # 1.Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "svg"

# %% [markdown]
# # 2.Importing the Datas

# %%
try:
    raw_df = pd.read_csv('Zomato_Mumbai_Dataset_2.csv', delimiter='|', error_bad_lines=False)
except pd.errors.ParserError as e:
        print("Error:", e)
# Out:
# b'Skipping line 1661: expected 12 fields, saw 14\n'

# %%
raw_df
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15075  Hari Om Snack Bar   350
# 15076           PitaBurg   400
# 15077     Uncha Otlawala   300
# 15078     Mandarin Panda   400
# 15079      ,,,,,,,,,,,,   NaN
#
#                                          CUSINE_CATEGORY    CITY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...  Mumbai
# 1                           Desserts,Ice Cream,Beverages  Mumbai
# 2                                          Asian,Chinese  Mumbai
# 3                                          Modern Indian  Mumbai
# 4                       North Indian,Chinese,Continental  Mumbai
# ...                                                  ...     ...
# 15075                     Fast Food,South Indian,Chinese  Mumbai
# 15076                                 Fast Food,Lebanese  Mumbai
# 15077                                 Desserts,Ice Cream  Mumbai
# 15078                              Desserts,Chinese,Thai  Mumbai
# 15079                                                NaN     NaN
#
#                                                   REGION  \
# 0      First International Financial Centre-- Bandra ...
# 1                                                  Mahim
# 2                                                   Juhu
# 3                                   Bandra Kurla Complex
# 4                                   Bandra Kurla Complex
# ...                                                  ...
# 15075                                     Kandivali West
# 15076                                        Lower Parel
# 15077                                     Kandivali West
# 15078                                         Malad West
# 15079                                                NaN
#
#                                                      URL PAGE NO  \
# 0      https://www.zomato.com/mumbai/hitchki-bandra-k...       1
# 1      https://www.zomato.com/mumbai/baba-falooda-mah...       1
# 2      https://www.zomato.com/mumbai/chin-chin-chu-ju...       1
# 3      https://www.zomato.com/mumbai/butterfly-high-b...       1
# 4      https://www.zomato.com/mumbai/bkc-dive-bandra-...       1
# ...                                                  ...     ...
# 15075  https://www.zomato.com/mumbai/hari-om-snack-ba...      99
# 15076  https://www.zomato.com/mumbai/pitaburg-lower-p...      99
# 15077  https://www.zomato.com/mumbai/uncha-otlawala-1...      99
# 15078  https://www.zomato.com/mumbai/mandarin-panda-m...      99
# 15079                                                NaN     NaN
#
#           CUSINE TYPE                                         TIMING  \
# 0       Casual Dining                       12noon to 130am(Mon-Sun)
# 1      Dessert Parlor                            2pm to 1am(Mon-Sun)
# 2       Casual Dining                         12noon to 1am(Mon-Sun)
# 3                 Bar                       12noon to 130am(Mon-Sun)
# 4                 Bar                         1130am to 1am(Mon-Sun)
# ...               ...                                            ...
# 15075     Quick Bites                         11am to 230am(Mon-Sun)
# 15076            none  11am to 11pm(Mon,Tue,Wed,Thu,Sun),11am to ...
# 15077  Dessert Parlor                         9am to 1230AM(Mon-Sun)
# 15078            none            12noon to 330pm,7pm to 1am(Mon-Sun)
# 15079             NaN                                            NaN
#
#        RATING_TYPE RATING VOTES,,,,,,,,,,,,
# 0        Excellent    4.9         3529,,,,,
# 1        Very Good    4.4    1723,,,,,,,,,,
# 2        Very Good    4.2    337,,,,,,,,,,,
# 3        Very Good    4.3  1200,,,,,,,,,,,,
# 4      Ve?mi dobr?    4.4    5995,,,,,,,,,,
# ...            ...    ...               ...
# 15075         Good    3.7      64,,,,,,,,,,
# 15076      Average    3.4          99,,,,,,
# 15077         Good    3.5     29,,,,,,,,,,,
# 15078         Good    3.7      121,,,,,,,,,
# 15079          NaN    NaN               NaN
#
# [15080 rows x 12 columns]

# %%
raw_df.rename(columns={'VOTES,,,,,,,,,,,,':'VOTES'},inplace=True)

# %%
raw_df
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15075  Hari Om Snack Bar   350
# 15076           PitaBurg   400
# 15077     Uncha Otlawala   300
# 15078     Mandarin Panda   400
# 15079      ,,,,,,,,,,,,   NaN
#
#                                          CUSINE_CATEGORY    CITY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...  Mumbai
# 1                           Desserts,Ice Cream,Beverages  Mumbai
# 2                                          Asian,Chinese  Mumbai
# 3                                          Modern Indian  Mumbai
# 4                       North Indian,Chinese,Continental  Mumbai
# ...                                                  ...     ...
# 15075                     Fast Food,South Indian,Chinese  Mumbai
# 15076                                 Fast Food,Lebanese  Mumbai
# 15077                                 Desserts,Ice Cream  Mumbai
# 15078                              Desserts,Chinese,Thai  Mumbai
# 15079                                                NaN     NaN
#
#                                                   REGION  \
# 0      First International Financial Centre-- Bandra ...
# 1                                                  Mahim
# 2                                                   Juhu
# 3                                   Bandra Kurla Complex
# 4                                   Bandra Kurla Complex
# ...                                                  ...
# 15075                                     Kandivali West
# 15076                                        Lower Parel
# 15077                                     Kandivali West
# 15078                                         Malad West
# 15079                                                NaN
#
#                                                      URL PAGE NO  \
# 0      https://www.zomato.com/mumbai/hitchki-bandra-k...       1
# 1      https://www.zomato.com/mumbai/baba-falooda-mah...       1
# 2      https://www.zomato.com/mumbai/chin-chin-chu-ju...       1
# 3      https://www.zomato.com/mumbai/butterfly-high-b...       1
# 4      https://www.zomato.com/mumbai/bkc-dive-bandra-...       1
# ...                                                  ...     ...
# 15075  https://www.zomato.com/mumbai/hari-om-snack-ba...      99
# 15076  https://www.zomato.com/mumbai/pitaburg-lower-p...      99
# 15077  https://www.zomato.com/mumbai/uncha-otlawala-1...      99
# 15078  https://www.zomato.com/mumbai/mandarin-panda-m...      99
# 15079                                                NaN     NaN
#
#           CUSINE TYPE                                         TIMING  \
# 0       Casual Dining                       12noon to 130am(Mon-Sun)
# 1      Dessert Parlor                            2pm to 1am(Mon-Sun)
# 2       Casual Dining                         12noon to 1am(Mon-Sun)
# 3                 Bar                       12noon to 130am(Mon-Sun)
# 4                 Bar                         1130am to 1am(Mon-Sun)
# ...               ...                                            ...
# 15075     Quick Bites                         11am to 230am(Mon-Sun)
# 15076            none  11am to 11pm(Mon,Tue,Wed,Thu,Sun),11am to ...
# 15077  Dessert Parlor                         9am to 1230AM(Mon-Sun)
# 15078            none            12noon to 330pm,7pm to 1am(Mon-Sun)
# 15079             NaN                                            NaN
#
#        RATING_TYPE RATING             VOTES
# 0        Excellent    4.9         3529,,,,,
# 1        Very Good    4.4    1723,,,,,,,,,,
# 2        Very Good    4.2    337,,,,,,,,,,,
# 3        Very Good    4.3  1200,,,,,,,,,,,,
# 4      Ve?mi dobr?    4.4    5995,,,,,,,,,,
# ...            ...    ...               ...
# 15075         Good    3.7      64,,,,,,,,,,
# 15076      Average    3.4          99,,,,,,
# 15077         Good    3.5     29,,,,,,,,,,,
# 15078         Good    3.7      121,,,,,,,,,
# 15079          NaN    NaN               NaN
#
# [15080 rows x 12 columns]

# %%
raw_df['VOTES'].value_counts()
# Out:
# VOTES,,,,,,,,,,,,    942
# -,,,,,,,,,,,         908
# -,,,,,,,,,,,,        794
# -,,,,,,,,,,          442
# NEW,,,,,,,,,,,       363
#                     ...
# 16,,,,                 1
# 569,,,,,,,,,,          1
# 346,,,,,,,,,           1
# 239,,,,,,,,            1
# 2602,,,,,,,,,          1
# Name: VOTES, Length: 2922, dtype: int64

# %%
raw_df['VOTES'] = raw_df['VOTES'].str.replace ('- ','', regex=True)

# %%
raw_df['VOTES'] = raw_df['VOTES'].str.replace ('-,,,,,,,,,, ','', regex=True)

# %%
raw_df['VOTES'] = raw_df['VOTES'].str.replace (',,,,,,,,','', regex=True)

# %%
raw_df['VOTES'] = raw_df['VOTES'].str.replace (',,,','', regex=True)

# %%
raw_df['VOTES'] = raw_df['VOTES'].str.replace (',,','', regex=True)

# %%
raw_df['VOTES'] = raw_df['VOTES'].str.replace (',','', regex=True)

# %%
raw_df['VOTES'].value_counts()
# Out:
# -        2354
# NEW       953
# VOTES     942
# 4         363
# 5         320
#          ...
# 463         1
# 1103        1
# 984         1
# 1560        1
# 2528        1
# Name: VOTES, Length: 1124, dtype: int64

# %%
raw_df
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15075  Hari Om Snack Bar   350
# 15076           PitaBurg   400
# 15077     Uncha Otlawala   300
# 15078     Mandarin Panda   400
# 15079      ,,,,,,,,,,,,   NaN
#
#                                          CUSINE_CATEGORY    CITY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...  Mumbai
# 1                           Desserts,Ice Cream,Beverages  Mumbai
# 2                                          Asian,Chinese  Mumbai
# 3                                          Modern Indian  Mumbai
# 4                       North Indian,Chinese,Continental  Mumbai
# ...                                                  ...     ...
# 15075                     Fast Food,South Indian,Chinese  Mumbai
# 15076                                 Fast Food,Lebanese  Mumbai
# 15077                                 Desserts,Ice Cream  Mumbai
# 15078                              Desserts,Chinese,Thai  Mumbai
# 15079                                                NaN     NaN
#
#                                                   REGION  \
# 0      First International Financial Centre-- Bandra ...
# 1                                                  Mahim
# 2                                                   Juhu
# 3                                   Bandra Kurla Complex
# 4                                   Bandra Kurla Complex
# ...                                                  ...
# 15075                                     Kandivali West
# 15076                                        Lower Parel
# 15077                                     Kandivali West
# 15078                                         Malad West
# 15079                                                NaN
#
#                                                      URL PAGE NO  \
# 0      https://www.zomato.com/mumbai/hitchki-bandra-k...       1
# 1      https://www.zomato.com/mumbai/baba-falooda-mah...       1
# 2      https://www.zomato.com/mumbai/chin-chin-chu-ju...       1
# 3      https://www.zomato.com/mumbai/butterfly-high-b...       1
# 4      https://www.zomato.com/mumbai/bkc-dive-bandra-...       1
# ...                                                  ...     ...
# 15075  https://www.zomato.com/mumbai/hari-om-snack-ba...      99
# 15076  https://www.zomato.com/mumbai/pitaburg-lower-p...      99
# 15077  https://www.zomato.com/mumbai/uncha-otlawala-1...      99
# 15078  https://www.zomato.com/mumbai/mandarin-panda-m...      99
# 15079                                                NaN     NaN
#
#           CUSINE TYPE                                         TIMING  \
# 0       Casual Dining                       12noon to 130am(Mon-Sun)
# 1      Dessert Parlor                            2pm to 1am(Mon-Sun)
# 2       Casual Dining                         12noon to 1am(Mon-Sun)
# 3                 Bar                       12noon to 130am(Mon-Sun)
# 4                 Bar                         1130am to 1am(Mon-Sun)
# ...               ...                                            ...
# 15075     Quick Bites                         11am to 230am(Mon-Sun)
# 15076            none  11am to 11pm(Mon,Tue,Wed,Thu,Sun),11am to ...
# 15077  Dessert Parlor                         9am to 1230AM(Mon-Sun)
# 15078            none            12noon to 330pm,7pm to 1am(Mon-Sun)
# 15079             NaN                                            NaN
#
#        RATING_TYPE RATING VOTES
# 0        Excellent    4.9  3529
# 1        Very Good    4.4  1723
# 2        Very Good    4.2   337
# 3        Very Good    4.3  1200
# 4      Ve?mi dobr?    4.4  5995
# ...            ...    ...   ...
# 15075         Good    3.7    64
# 15076      Average    3.4    99
# 15077         Good    3.5    29
# 15078         Good    3.7   121
# 15079          NaN    NaN   NaN
#
# [15080 rows x 12 columns]

# %% [markdown]
# # 3. Getting Basic Information about the Dataset

# %%
raw_df.shape
# Out:
# (15080, 12)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15080 entries, 0 to 15079
# Data columns (total 12 columns):
# NAME               15080 non-null object
# PRICE              15075 non-null object
# CUSINE_CATEGORY    15074 non-null object
# CITY               15075 non-null object
# REGION             15075 non-null object
# URL                15075 non-null object
# PAGE NO            15075 non-null object
# CUSINE TYPE        15075 non-null object
# TIMING             15010 non-null object
# RATING_TYPE        15075 non-null object
# RATING             15061 non-null object
# VOTES              15061 non-null object
# dtypes: object(12)
# memory usage: 1.4+ MB

# %%
raw_df.describe()
# Out:
#          NAME  PRICE  CUSINE_CATEGORY    CITY  REGION    URL  PAGE NO  \
# count   15080  15075            15074   15075   15075  15075    15075
# unique  12719     69             3191      16     255  13810      958
# top      NAME    400  CUSINE_CATEGORY  Mumbai  REGION    URL  PAGE NO
# freq      942   2040              942   14119     942    942      942
#
#         CUSINE TYPE                 TIMING RATING_TYPE RATING  VOTES
# count         15075                  15010       15075  15061  15061
# unique           27                   2554          45     35   1124
# top     Quick Bites  11am to 11pm(Mon-Sun)     Average      -      -
# freq           5255                   1192        5108   2354   2354

# %% [markdown]
# # 4. Cleaning the dataset
# # a. Removing the redundunt rows of data

# %%
# Checking the Redundunt rows of Data

wrong_data=raw_df['PAGE NO']=='PAGE NO'
raw_df[wrong_data]
# Out:
#        NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE  \
# 15     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 31     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 47     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 63     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 79     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# ...     ...    ...              ...   ...     ...  ...      ...          ...
# 14999  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15015  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15031  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15047  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15063  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
#
#        TIMING  RATING_TYPE  RATING  VOTES
# 15     TIMING  RATING_TYPE  RATING  VOTES
# 31     TIMING  RATING_TYPE  RATING  VOTES
# 47     TIMING  RATING_TYPE  RATING  VOTES
# 63     TIMING  RATING_TYPE  RATING  VOTES
# 79     TIMING  RATING_TYPE  RATING  VOTES
# ...       ...          ...     ...    ...
# 14999  TIMING  RATING_TYPE  RATING  VOTES
# 15015  TIMING  RATING_TYPE  RATING  VOTES
# 15031  TIMING  RATING_TYPE  RATING  VOTES
# 15047  TIMING  RATING_TYPE  RATING  VOTES
# 15063  TIMING  RATING_TYPE  RATING  VOTES
#
# [942 rows x 12 columns]

# %%
## Performing Negation of the wrong dataset and then storing the correct data back in the raw_df DataFrame
## This permamnently remove the wrong data from the original dataframe

raw_df = raw_df[~wrong_data]

# %%
raw_df
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15075  Hari Om Snack Bar   350
# 15076           PitaBurg   400
# 15077     Uncha Otlawala   300
# 15078     Mandarin Panda   400
# 15079      ,,,,,,,,,,,,   NaN
#
#                                          CUSINE_CATEGORY    CITY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...  Mumbai
# 1                           Desserts,Ice Cream,Beverages  Mumbai
# 2                                          Asian,Chinese  Mumbai
# 3                                          Modern Indian  Mumbai
# 4                       North Indian,Chinese,Continental  Mumbai
# ...                                                  ...     ...
# 15075                     Fast Food,South Indian,Chinese  Mumbai
# 15076                                 Fast Food,Lebanese  Mumbai
# 15077                                 Desserts,Ice Cream  Mumbai
# 15078                              Desserts,Chinese,Thai  Mumbai
# 15079                                                NaN     NaN
#
#                                                   REGION  \
# 0      First International Financial Centre-- Bandra ...
# 1                                                  Mahim
# 2                                                   Juhu
# 3                                   Bandra Kurla Complex
# 4                                   Bandra Kurla Complex
# ...                                                  ...
# 15075                                     Kandivali West
# 15076                                        Lower Parel
# 15077                                     Kandivali West
# 15078                                         Malad West
# 15079                                                NaN
#
#                                                      URL PAGE NO  \
# 0      https://www.zomato.com/mumbai/hitchki-bandra-k...       1
# 1      https://www.zomato.com/mumbai/baba-falooda-mah...       1
# 2      https://www.zomato.com/mumbai/chin-chin-chu-ju...       1
# 3      https://www.zomato.com/mumbai/butterfly-high-b...       1
# 4      https://www.zomato.com/mumbai/bkc-dive-bandra-...       1
# ...                                                  ...     ...
# 15075  https://www.zomato.com/mumbai/hari-om-snack-ba...      99
# 15076  https://www.zomato.com/mumbai/pitaburg-lower-p...      99
# 15077  https://www.zomato.com/mumbai/uncha-otlawala-1...      99
# 15078  https://www.zomato.com/mumbai/mandarin-panda-m...      99
# 15079                                                NaN     NaN
#
#           CUSINE TYPE                                         TIMING  \
# 0       Casual Dining                       12noon to 130am(Mon-Sun)
# 1      Dessert Parlor                            2pm to 1am(Mon-Sun)
# 2       Casual Dining                         12noon to 1am(Mon-Sun)
# 3                 Bar                       12noon to 130am(Mon-Sun)
# 4                 Bar                         1130am to 1am(Mon-Sun)
# ...               ...                                            ...
# 15075     Quick Bites                         11am to 230am(Mon-Sun)
# 15076            none  11am to 11pm(Mon,Tue,Wed,Thu,Sun),11am to ...
# 15077  Dessert Parlor                         9am to 1230AM(Mon-Sun)
# 15078            none            12noon to 330pm,7pm to 1am(Mon-Sun)
# 15079             NaN                                            NaN
#
#        RATING_TYPE RATING VOTES
# 0        Excellent    4.9  3529
# 1        Very Good    4.4  1723
# 2        Very Good    4.2   337
# 3        Very Good    4.3  1200
# 4      Ve?mi dobr?    4.4  5995
# ...            ...    ...   ...
# 15075         Good    3.7    64
# 15076      Average    3.4    99
# 15077         Good    3.5    29
# 15078         Good    3.7   121
# 15079          NaN    NaN   NaN
#
# [14138 rows x 12 columns]

# %%
# Dropping columns which are not required for further analysis

raw_df.drop(['URL', 'PAGE NO', 'CITY'], axis = 1, inplace=True)
# Out:
# C:\Users\Hi\anaconda3\envs\ven\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
raw_df.head()
# Out:
#              NAME PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800                                      Asian,Chinese
# 3  Butterfly High  1000                                      Modern Indian
# 4       BKC  DIVE  1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#                      TIMING  RATING_TYPE RATING VOTES
# 0  12noon to 130am(Mon-Sun)    Excellent    4.9  3529
# 1       2pm to 1am(Mon-Sun)    Very Good    4.4  1723
# 2    12noon to 1am(Mon-Sun)    Very Good    4.2   337
# 3  12noon to 130am(Mon-Sun)    Very Good    4.3  1200
# 4    1130am to 1am(Mon-Sun)  Ve?mi dobr?    4.4  5995

# %% [markdown]
# # b. Removing the Null Records

# %%
 # Checking for Null records

raw_df.isnull().sum()
# Out:
# NAME                0
# PRICE               5
# CUSINE_CATEGORY     6
# REGION              5
# CUSINE TYPE         5
# TIMING             70
# RATING_TYPE         5
# RATING             19
# VOTES              19
# dtype: int64

# %%
# Checking for a null row


raw_df[raw_df['PRICE'].isnull()]
# Out:
#                                                     NAME PRICE  \
# 10042  Vinay Sandwiches, Maggi & Pasta|"200"|"Fast Fo...   NaN
# 11297  Govekar's Cake , Chocolates & More|"300"|"Bake...   NaN
# 12671  My Urja, Milky Way|"100"|"Fast Food"|"Mumbai"|...   NaN
# 12946  Breads, Cakes N' More|"200"|"Bakery"|"Mumbai"|...   NaN
# 15079                                      ,,,,,,,,,,,,   NaN
#
#       CUSINE_CATEGORY REGION CUSINE TYPE TIMING RATING_TYPE RATING VOTES
# 10042             NaN    NaN         NaN    NaN         NaN    NaN   NaN
# 11297             NaN    NaN         NaN    NaN         NaN    NaN   NaN
# 12671             NaN    NaN         NaN    NaN         NaN    NaN   NaN
# 12946             NaN    NaN         NaN    NaN         NaN    NaN   NaN
# 15079             NaN    NaN         NaN    NaN         NaN    NaN   NaN

# %%
# Droping the above row from the dataset
raw_df = raw_df.drop([10042,11297,12671,12946,15079], axis=0)

# %%
raw_df
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15074    Tirupati Balaji   500
# 15075  Hari Om Snack Bar   350
# 15076           PitaBurg   400
# 15077     Uncha Otlawala   300
# 15078     Mandarin Panda   400
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 1                           Desserts,Ice Cream,Beverages
# 2                                          Asian,Chinese
# 3                                          Modern Indian
# 4                       North Indian,Chinese,Continental
# ...                                                  ...
# 15074                     Chinese,Fast Food,North Indian
# 15075                     Fast Food,South Indian,Chinese
# 15076                                 Fast Food,Lebanese
# 15077                                 Desserts,Ice Cream
# 15078                              Desserts,Chinese,Thai
#
#                                                   REGION     CUSINE TYPE  \
# 0      First International Financial Centre-- Bandra ...   Casual Dining
# 1                                                  Mahim  Dessert Parlor
# 2                                                   Juhu   Casual Dining
# 3                                   Bandra Kurla Complex             Bar
# 4                                   Bandra Kurla Complex             Bar
# ...                                                  ...             ...
# 15074                            Oshiwara-- Andheri West   Casual Dining
# 15075                                     Kandivali West     Quick Bites
# 15076                                        Lower Parel            none
# 15077                                     Kandivali West  Dessert Parlor
# 15078                                         Malad West            none
#
#                                               TIMING  RATING_TYPE RATING VOTES
# 0                           12noon to 130am(Mon-Sun)    Excellent    4.9  3529
# 1                                2pm to 1am(Mon-Sun)    Very Good    4.4  1723
# 2                             12noon to 1am(Mon-Sun)    Very Good    4.2   337
# 3                           12noon to 130am(Mon-Sun)    Very Good    4.3  1200
# 4                             1130am to 1am(Mon-Sun)  Ve?mi dobr?    4.4  5995
# ...                                              ...          ...    ...   ...
# 15074       8am to 11pm,12midnight to 115am(Mon-Sun)         Good    3.5   267
# 15075                         11am to 230am(Mon-Sun)         Good    3.7    64
# 15076  11am to 11pm(Mon,Tue,Wed,Thu,Sun),11am to ...      Average    3.4    99
# 15077                         9am to 1230AM(Mon-Sun)         Good    3.5    29
# 15078            12noon to 330pm,7pm to 1am(Mon-Sun)         Good    3.7   121
#
# [14133 rows x 9 columns]

# %%
# Replacing the other null records with NA

raw_df.fillna('NA', inplace=True)

# %%
# Confirming all the null records are correct 

raw_df.isnull().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# dtype: int64

# %% [markdown]
# # c. Converting the DataTypes of numerical columns to numeric dataype

# %%
# Checking for text values in the column before converting it to numeric datatype

raw_df['RATING'].value_counts()
# Out:
# -          2354
# 3.5        1094
# 3.4        1034
# 3.6         956
# NEW         953
# 3.3         926
# 3.7         915
# 3.2         801
# 3.8         781
# 3.1         732
# 3.0         622
# 3.9         595
# 2.9         409
# 4.0         407
# 2.8         309
# 4.1         298
# 4.2         199
# 2.7         170
# 4.3         148
# 4.4          99
# 2.6          77
# Opening      57
# 4.5          46
# 2.5          39
# 4.6          32
# 2.4          26
# NA           14
# 4.7          13
# 2.3          10
# 2.1           5
# 4.8           4
# 2.2           4
# 4.9           2
# 1.8           1
# 2.0           1
# Name: RATING, dtype: int64

# %%
# Replacing the text values with '0'

raw_df['RATING'].replace(to_replace=['-','NEW','Opening','NA'], value='0', inplace=True)

# %%
raw_df['RATING'].value_counts()
# Out:
# 0      3378
# 3.5    1094
# 3.4    1034
# 3.6     956
# 3.3     926
# 3.7     915
# 3.2     801
# 3.8     781
# 3.1     732
# 3.0     622
# 3.9     595
# 2.9     409
# 4.0     407
# 2.8     309
# 4.1     298
# 4.2     199
# 2.7     170
# 4.3     148
# 4.4      99
# 2.6      77
# 4.5      46
# 2.5      39
# 4.6      32
# 2.4      26
# 4.7      13
# 2.3      10
# 2.1       5
# 2.2       4
# 4.8       4
# 4.9       2
# 1.8       1
# 2.0       1
# Name: RATING, dtype: int64

# %%
raw_df['VOTES'].value_counts()
# Out:
# -       2354
# NEW      953
# 4        363
# 5        320
# 6        288
#         ...
# 7350       1
# 664        1
# 1457       1
# 741        1
# 2528       1
# Name: VOTES, Length: 1124, dtype: int64

# %%
raw_df['PRICE'].replace(to_replace=['-','NA','inf','"'], value='0', inplace=True)

# %%
raw_df['PRICE'].value_counts()
# Out:
# 400     2040
# 500     1952
# 300     1932
# 200     1172
# 600     1062
#         ...
# 2700       1
# 1550       1
# 5000       1
# 1650       1
# 5          1
# Name: PRICE, Length: 68, dtype: int64

# %%
raw_df['PRICE'].replace(to_replace=['NA'], value='0', inplace=True)

# %%
raw_df.drop(raw_df[raw_df['PRICE'] == '150"'].index, inplace=True)

# %%
raw_df['PRICE'].value_counts()
# Out:
# 400     2040
# 500     1952
# 300     1932
# 200     1172
# 600     1062
#         ...
# 505        1
# 1550       1
# 2700       1
# 3502       1
# 5          1
# Name: PRICE, Length: 67, dtype: int64

# %%
raw_df['PRICE'].dtypes
# Out:
# dtype('O')

# %%
raw_df['VOTES'].replace(to_replace=['-','NEW'], value='0', inplace=True)

# %%
raw_df['VOTES'].value_counts()
# Out:
# 0       3308
# 4        363
# 5        320
# 6        288
# 7        277
#         ...
# 748        1
# 7350       1
# 1457       1
# 741        1
# 2528       1
# Name: VOTES, Length: 1122, dtype: int64

# %%
raw_df.dtypes
# Out:
# NAME               object
# PRICE              object
# CUSINE_CATEGORY    object
# REGION             object
# CUSINE TYPE        object
# TIMING             object
# RATING_TYPE        object
# RATING             object
# VOTES              object
# dtype: object

# %%
# Changing Data Type of the numerical columns
raw_df['PRICE'] = pd.to_numeric(raw_df['PRICE'].astype('float64'), errors='coerce')

raw_df['VOTES'] = pd.to_numeric(raw_df['VOTES'].astype('float64'), errors='coerce')

raw_df['RATING'] = pd.to_numeric(raw_df['RATING'].astype('float64'), errors='coerce')
# Out:
# C:\Users\Hi\anaconda3\envs\ven\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Hi\anaconda3\envs\ven\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Hi\anaconda3\envs\ven\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10753 entries, 0 to 15078
# Data columns (total 10 columns):
# NAME               10753 non-null object
# PRICE              10753 non-null float64
# CUSINE_CATEGORY    10753 non-null object
# REGION             10753 non-null object
# CUSINE TYPE        10753 non-null object
# TIMING             10753 non-null object
# RATING_TYPE        10753 non-null object
# RATING             10753 non-null float64
# VOTES              10753 non-null float64
# DAYS_OPEN          10753 non-null object
# dtypes: float64(3), object(7)
# memory usage: 924.1+ KB

# %%
raw_df.isnull().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# DAYS_OPEN          0
# dtype: int64

# %%
raw_df.fillna('NA', inplace=True)
# Out:
# C:\Users\Hi\anaconda3\envs\ven\lib\site-packages\pandas\core\frame.py:4259: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
raw_df.isnull().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# DAYS_OPEN          0
# dtype: int64

# %% [markdown]
# # d. Working with 'Timing' column

# %%
raw_df['TIMING'].value_counts()
# Out:
# 11am to 11pm                           777
# 11am to 12midnight                     517
# 12noon to 12midnight                   399
# Closed                                 263
# 11am to 1130pm                         243
#                                       ...
# 12noon to 12pm                           1
# 12noon to 4pm,7pm to 1140pm              1
# 1130am to 3pm,6pm to 4am                 1
# 1130am to 330pm,7pm to 1115pm            1
# 1130am to 230pm,630pm to 12midnight      1
# Name: TIMING, Length: 1359, dtype: int64

# %%
# Splitting the column and storing it in temp_df dataframe 

temp_df = raw_df['TIMING'].str.split("(", n = 1, expand = True)
temp_df
# Out:
#                                      0
# 0                      12noon to 130am
# 1                           2pm to 1am
# 2                        12noon to 1am
# 3                      12noon to 130am
# 4                        1130am to 1am
# ...                                ...
# 15074  8am to 11pm,12midnight to 115am
# 15075                    11am to 230am
# 15076                     11am to 11pm
# 15077                    9am to 1230AM
# 15078       12noon to 330pm,7pm to 1am
#
# [10753 rows x 1 columns]

# %%
# Assigning the columns back to the raw_df dataframe


raw_df['TIMING'] = temp_df[0]
raw_df['DAYS_OPEN'] = temp_df[1]
raw_df.head()
# Out:
# C:\Users\Hi\anaconda3\envs\ven\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\envs\ven\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     375             try:
# --> 376                 return self._range.index(new_key)
#     377             except ValueError:
#
# ValueError: 1 is not in range
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13740\3044473215.py in <module>
#       3
#       4 raw_df['TIMING'] = temp_df[0]
# ----> 5 raw_df['DAYS_OPEN'] = temp_df[1]
#       6 raw_df.head()
#
# ~\anaconda3\envs\ven\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~\anaconda3\envs\ven\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     376                 return self._range.index(new_key)
#     377             except ValueError:
# --> 378                 raise KeyError(key)
#     379         return super().get_loc(key, method=method, tolerance=tolerance)
#     380
#
# KeyError: 1

# %%
# Removing the bracket character from Days column

raw_df['DAYS_OPEN'] = raw_df['DAYS_OPEN'].str.replace(')','',regex=True)
raw_df.head()
# Out:
# C:\Users\Hi\anaconda3\envs\ven\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              NAME   PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200.0  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400.0                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800.0                                      Asian,Chinese
# 3  Butterfly High  1000.0                                      Modern Indian
# 4       BKC  DIVE  1200.0                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#             TIMING RATING_TYPE  RATING   VOTES DAYS_OPEN
# 0  12noon to 130am   Excellent     4.9  3529.0   Mon-Sun
# 1       2pm to 1am   Very Good     4.4  1723.0   Mon-Sun
# 2    12noon to 1am   Very Good     4.2   337.0   Mon-Sun
# 3  12noon to 130am   Very Good     4.3  1200.0   Mon-Sun
# 4    1130am to 1am   Very Good     4.4  5995.0   Mon-Sun

# %%
# Checking for Null records in DAYS_OPEN column

raw_df.isnull().sum()
# Out:
# NAME                0
# PRICE               0
# CUSINE_CATEGORY     0
# REGION              0
# CUSINE TYPE         0
# TIMING              0
# RATING_TYPE         0
# RATING              0
# VOTES               0
# DAYS_OPEN          85
# dtype: int64

# %%
raw_df['DAYS_OPEN'].fillna(0,inplace=True)

# %%
raw_df.isnull().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# DAYS_OPEN          0
# dtype: int64

# %%
# Checking info of all the columns
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10753 entries, 0 to 15078
# Data columns (total 10 columns):
# NAME               10753 non-null object
# PRICE              10753 non-null float64
# CUSINE_CATEGORY    10753 non-null object
# REGION             10753 non-null object
# CUSINE TYPE        10753 non-null object
# TIMING             10753 non-null object
# RATING_TYPE        10753 non-null object
# RATING             10753 non-null float64
# VOTES              10753 non-null float64
# DAYS_OPEN          10753 non-null object
# dtypes: float64(3), object(7)
# memory usage: 924.1+ KB

# %% [markdown]
# # e. Removing the restaurant records whose Rating or Votes is 0

# %%
useless_data = (raw_df['RATING'] == 0.0) | (raw_df['VOTES'] == 0)
raw_df[useless_data]
# Out:
# Empty DataFrame
# Columns: [NAME, PRICE, CUSINE_CATEGORY, REGION, CUSINE TYPE, TIMING, RATING_TYPE, RATING, VOTES, DAYS_OPEN]
# Index: []

# %%
## Performing Negation of the useless dataset and then storing the correct data back in the raw_df DataFrame
## This permamnently remove the wrong data from the original dataframe

raw_df = raw_df[~useless_data]

# %%
raw_df
# Out:
#                     NAME   PRICE  \
# 0                Hitchki  1200.0
# 1           Baba Falooda   400.0
# 2          Chin Chin Chu  1800.0
# 3         Butterfly High  1000.0
# 4              BKC  DIVE  1200.0
# ...                  ...     ...
# 15074    Tirupati Balaji   500.0
# 15075  Hari Om Snack Bar   350.0
# 15076           PitaBurg   400.0
# 15077     Uncha Otlawala   300.0
# 15078     Mandarin Panda   400.0
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 1                           Desserts,Ice Cream,Beverages
# 2                                          Asian,Chinese
# 3                                          Modern Indian
# 4                       North Indian,Chinese,Continental
# ...                                                  ...
# 15074                     Chinese,Fast Food,North Indian
# 15075                     Fast Food,South Indian,Chinese
# 15076                                 Fast Food,Lebanese
# 15077                                 Desserts,Ice Cream
# 15078                              Desserts,Chinese,Thai
#
#                                                   REGION     CUSINE TYPE  \
# 0      First International Financial Centre-- Bandra ...   Casual Dining
# 1                                                  Mahim  Dessert Parlor
# 2                                                   Juhu   Casual Dining
# 3                                   Bandra Kurla Complex             Bar
# 4                                   Bandra Kurla Complex             Bar
# ...                                                  ...             ...
# 15074                            Oshiwara-- Andheri West   Casual Dining
# 15075                                     Kandivali West     Quick Bites
# 15076                                        Lower Parel            none
# 15077                                     Kandivali West  Dessert Parlor
# 15078                                         Malad West            none
#
#                                 TIMING RATING_TYPE  RATING   VOTES  \
# 0                      12noon to 130am   Excellent     4.9  3529.0
# 1                           2pm to 1am   Very Good     4.4  1723.0
# 2                        12noon to 1am   Very Good     4.2   337.0
# 3                      12noon to 130am   Very Good     4.3  1200.0
# 4                        1130am to 1am   Very Good     4.4  5995.0
# ...                                ...         ...     ...     ...
# 15074  8am to 11pm,12midnight to 115am        Good     3.5   267.0
# 15075                    11am to 230am        Good     3.7    64.0
# 15076                     11am to 11pm     Average     3.4    99.0
# 15077                    9am to 1230AM        Good     3.5    29.0
# 15078       12noon to 330pm,7pm to 1am        Good     3.7   121.0
#
#                              DAYS_OPEN
# 0                              Mon-Sun
# 1                              Mon-Sun
# 2                              Mon-Sun
# 3                              Mon-Sun
# 4                              Mon-Sun
# ...                                ...
# 15074                          Mon-Sun
# 15075                          Mon-Sun
# 15076  Mon,Tue,Wed,Thu,Sun,11am to ...
# 15077                          Mon-Sun
# 15078                          Mon-Sun
#
# [10753 rows x 10 columns]

# %% [markdown]
# # f. Working on 'RATING_TYPE' Column

# %%
# Checking the unique values in the column

raw_df['RATING_TYPE'].value_counts()
# Out:
# Average      5110
# Good         4339
# Very Good    1147
# Excellent      96
# Poor           57
# Very Poor       4
# Name: RATING_TYPE, dtype: int64

# %%
# Translating the texts into proper English text
raw_df['RATING_TYPE'].replace(to_replace='Excelente' , value='Excellent', inplace=True)

raw_df['RATING_TYPE'].replace(to_replace=['Veľmi dobré','Bardzo dobrze','Muy Bueno','Velmi dobré'] , value='Very Good',inplace=True)
                              
raw_df['RATING_TYPE'].replace(to_replace=['Skvělá volba','Dobrze','Bueno','Buono','Dobré','Bom','Skvělé'] , value='Good',inplace=True)
                              
raw_df['RATING_TYPE'].replace(to_replace=['Priemer','Média','Çok iyi'] , value='Average', inplace=True)

raw_df['RATING_TYPE'].replace(to_replace=['Průměr','Promedio','Ortalama','Muito Bom','İyi'] , value='Poor', inplace=True)

raw_df['RATING_TYPE'].replace(to_replace=['Baik','Biasa','Media','Sangat Baik'] , value='Very Poor', inplace=True)

# %%
raw_df['RATING_TYPE'].value_counts()
# Out:
# Average      5110
# Good         4339
# Very Good    1147
# Excellent      96
# Poor           57
# Very Poor       4
# Name: RATING_TYPE, dtype: int64

# %%
raw_df['RATING_TYPE'].replace(to_replace=['Ve?mi dobr?','Velmi dobr?'], value='Very Good', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['Dobr?','Skv?l? volba','Skv?l?'] , value='Good', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['?yi','Pr?m?r'],value='Poor', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['?ok iyi',],value='Average', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['M?dia'],value='Average', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['Very good'],value='Very Good', inplace=True)

# %%
raw_df['RATING_TYPE'].value_counts()
# Out:
# Average      5110
# Good         4339
# Very Good    1147
# Excellent      96
# Poor           57
# Very Poor       4
# Name: RATING_TYPE, dtype: int64

# %% [markdown]
# # g. Working on 'REGION' Column

# %%
raw_df['REGION'].value_counts()
# Out:
# Mira Road                         404
# Malad West                        305
# Chembur                           277
# Kharghar                          268
# Borivali West                     264
#                                  ...
# Cooling Tower-- Goregaon East       1
# ITC Grand Central-- Parel           1
# Fariyas Hotel-- Colaba              1
# Pallavi Avida-- Kalamboli           1
# Sofitel-- Bandra Kurla Complex      1
# Name: REGION, Length: 237, dtype: int64

# %%
# Removing the irrelevant text from the Region column

raw_df['REGION'] = raw_df['REGION'].str.replace('[a-zA-Z].+-- ','',regex=True)

# %%
# Removing the West & East from the Region column

raw_df['REGION'] = raw_df['REGION'].str.replace(' West| west| East| east','',regex=True)

# %%
raw_df['REGION'].value_counts()
# Out:
# Thane                725
# Mira Road            411
# Andheri              408
# Kandivali            376
# Malad                375
#                     ...
# Majiwada               3
# Flea Bazaar Caf?       3
# Panvel                 2
# Girgaon Chowpatty      1
# CBD Belapur            1
# Name: REGION, Length: 101, dtype: int64

# %%
# Replacing Small regions with Known region name

raw_df['REGION'] = raw_df['REGION'].str.replace('4 Bungalows|7 Andheri|Azad Nagar|Near Andheri Station|Veera Desai Area', 'New Link Road',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Bandra Kurla Complex','Bandra',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('CBD-Belapur','CBD Belapur',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Girgaon Chowpatty','Chowpatty',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Dadar Shivaji Park','Dadar',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Flea Bazaar Café|Kamala Mills Compound','Lower Parel',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Runwal Green','Mulund',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Mumbai CST Area','Mumbai Central',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Kopar Khairane|Seawoods|Turbhe|Ulwe','Navi Mumbai',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('New Panvel|Old Panvel','Panvel',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Kamothe','Sion',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Ghodbunder Road|Majiwada','Thane',regex=True)

# %%
raw_df['REGION'].value_counts()
# Out:
# Thane               769
# Mira Road           411
# Andheri             408
# Bandra              376
# Kandivali           376
#                    ...
# Sewri                12
# Alibaug              10
# Gorai                 7
# Peddar Road           4
# Flea Bazaar Caf?      3
# Name: REGION, Length: 82, dtype: int64

# %% [markdown]
# # h. Removing Duplicate records

# %%
# Finding all the duplicate rows

raw_df[raw_df.duplicated()]
# Out:
#                                 NAME   PRICE  \
# 4063   Sai Sannidhi Restaurant & Bar  1000.0
# 4067                    Konkan Katta   400.0
# 4081                  Usmaniya Hotel   600.0
# 4082                    Gina's Cakes   450.0
# 4083          Konkanastha Lunch Home   400.0
# ...                              ...     ...
# 14199      Mezbaan Family Restaurant   350.0
# 14203               Jyoti Lunch Home   650.0
# 14252                        On Toes   900.0
# 14760                    Frosty Farm   400.0
# 14927               Shree Manu Sagar   300.0
#
#                             CUSINE_CATEGORY     REGION     CUSINE TYPE  \
# 4063                    North Indian,Konkan    Dahisar   Casual Dining
# 4067          Seafood,Maharashtrian,Malwani   Mahakali     Quick Bites
# 4081                                Mughlai       Fort   Casual Dining
# 4082                                 Bakery  Dombivali            none
# 4083                        Seafood,Malwani    Chakala   Casual Dining
# ...                                     ...        ...             ...
# 14199                       Chinese,Mughlai     Mumbra           Dhaba
# 14203  Chinese,North Indian,Seafood,Mughlai     Mulund   Casual Dining
# 14252          Italian,North Indian,Chinese      Malad   Casual Dining
# 14760          Ice Cream,Desserts,Fast Food      Malad  Dessert Parlor
# 14927           North Indian,Chinese,Indian   Ghansoli     Quick Bites
#
#                               TIMING RATING_TYPE  RATING  VOTES DAYS_OPEN
# 4063              11am to 12midnight        Good     3.7   99.0   Mon-Sun
# 4067   11am to 330pm,630pm to 1130pm        Good     3.5  181.0   Mon-Sun
# 4081                1030am to 1130pm     Average     3.2    8.0   Mon-Sun
# 4082                    11am to 11pm        Good     3.5   49.0   Mon-Sun
# 4083   12noon to 3pm,730pm to 1030pm        Good     3.5   44.0   Mon-Sun
# ...                              ...         ...     ...    ...       ...
# 14199               12noon to 1230AM     Average     2.8   97.0   Mon-Sun
# 14203                 11am to 1230AM        Good     3.5   49.0   Mon-Sun
# 14252    12noon to 3pm,7pm to 1230AM        Good     3.6   76.0   Mon-Sun
# 14760                  1pm to 1215AM        Good     3.6  120.0   Mon-Sun
# 14927  1130am to 415pm,7pm to 1215AM     Average     3.3   51.0   Mon-Sun
#
# [220 rows x 10 columns]

# %%
# Dropping all the duplicate rows

raw_df = raw_df.drop_duplicates()

# %%
raw_df
# Out:
#                     NAME   PRICE  \
# 0                Hitchki  1200.0
# 1           Baba Falooda   400.0
# 2          Chin Chin Chu  1800.0
# 3         Butterfly High  1000.0
# 4              BKC  DIVE  1200.0
# ...                  ...     ...
# 15074    Tirupati Balaji   500.0
# 15075  Hari Om Snack Bar   350.0
# 15076           PitaBurg   400.0
# 15077     Uncha Otlawala   300.0
# 15078     Mandarin Panda   400.0
#
#                                          CUSINE_CATEGORY       REGION  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...       Bandra
# 1                           Desserts,Ice Cream,Beverages        Mahim
# 2                                          Asian,Chinese         Juhu
# 3                                          Modern Indian       Bandra
# 4                       North Indian,Chinese,Continental       Bandra
# ...                                                  ...          ...
# 15074                     Chinese,Fast Food,North Indian      Andheri
# 15075                     Fast Food,South Indian,Chinese    Kandivali
# 15076                                 Fast Food,Lebanese  Lower Parel
# 15077                                 Desserts,Ice Cream    Kandivali
# 15078                              Desserts,Chinese,Thai        Malad
#
#           CUSINE TYPE                           TIMING RATING_TYPE  RATING  \
# 0       Casual Dining                  12noon to 130am   Excellent     4.9
# 1      Dessert Parlor                       2pm to 1am   Very Good     4.4
# 2       Casual Dining                    12noon to 1am   Very Good     4.2
# 3                 Bar                  12noon to 130am   Very Good     4.3
# 4                 Bar                    1130am to 1am   Very Good     4.4
# ...               ...                              ...         ...     ...
# 15074   Casual Dining  8am to 11pm,12midnight to 115am        Good     3.5
# 15075     Quick Bites                    11am to 230am        Good     3.7
# 15076            none                     11am to 11pm     Average     3.4
# 15077  Dessert Parlor                    9am to 1230AM        Good     3.5
# 15078            none       12noon to 330pm,7pm to 1am        Good     3.7
#
#         VOTES                        DAYS_OPEN
# 0      3529.0                          Mon-Sun
# 1      1723.0                          Mon-Sun
# 2       337.0                          Mon-Sun
# 3      1200.0                          Mon-Sun
# 4      5995.0                          Mon-Sun
# ...       ...                              ...
# 15074   267.0                          Mon-Sun
# 15075    64.0                          Mon-Sun
# 15076    99.0  Mon,Tue,Wed,Thu,Sun,11am to ...
# 15077    29.0                          Mon-Sun
# 15078   121.0                          Mon-Sun
#
# [10533 rows x 10 columns]

# %% [markdown]
# # 4. Copying the cleaned data into a new DataFrame

# %%
zomato_df = raw_df.copy()

# %%
zomato_df.head()
# Out:
#              NAME   PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200.0  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400.0                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800.0                                      Asian,Chinese
# 3  Butterfly High  1000.0                                      Modern Indian
# 4       BKC  DIVE  1200.0                   North Indian,Chinese,Continental
#
#    REGION     CUSINE TYPE           TIMING RATING_TYPE  RATING   VOTES  \
# 0  Bandra   Casual Dining  12noon to 130am   Excellent     4.9  3529.0
# 1   Mahim  Dessert Parlor       2pm to 1am   Very Good     4.4  1723.0
# 2    Juhu   Casual Dining    12noon to 1am   Very Good     4.2   337.0
# 3  Bandra             Bar  12noon to 130am   Very Good     4.3  1200.0
# 4  Bandra             Bar    1130am to 1am   Very Good     4.4  5995.0
#
#   DAYS_OPEN
# 0   Mon-Sun
# 1   Mon-Sun
# 2   Mon-Sun
# 3   Mon-Sun
# 4   Mon-Sun

# %% [markdown]
# # 5. Performing Exploratory Data Analysis
#
# # Q1) How many restaurants are in Mumbai for each type of cuisine?

# %%
fig = px.histogram(zomato_df, x='CUSINE TYPE', color='CUSINE TYPE',
 title= 'No. of Restaurants by Cuisine Type',
 labels={'CUSINE TYPE':'Cuisine Type'})
fig.show()

# %% [markdown]
# # Q2) What are the percentage of restaurants by Rating Type in Mumbai?

# %%
rating_type_df = zomato_df['RATING_TYPE'].value_counts().reset_index()
rating_type_df.rename(columns={'index':'RATING TYPE', 'RATING_TYPE':'COUNT OF RESTAURANTS'}, inplace=True)
rating_type_df
# Out:
#   RATING TYPE  COUNT OF RESTAURANTS
# 0     Average                  4978
# 1        Good                  4255
# 2   Very Good                  1144
# 3   Excellent                    96
# 4        Poor                    56
# 5   Very Poor                     4

# %%
fig = px.pie(rating_type_df, names='RATING TYPE', values='COUNT OF RESTAURANTS', color='RATING TYPE',
      title='Percentage of Restaurants by Rating Type').update_traces(textposition='inside', textinfo='percent+label')
fig.show()

# %% [markdown]
# # Q3) Which are the Top 10 highest rated Seafood Restaurant in Mumbai?

# %%
seafood_df = zomato_df[zomato_df['CUSINE_CATEGORY'].str.contains('Seafood')]
seafood_df.sort_values(by='RATING',ascending=False).head(10)
# Out:
#                                           NAME   PRICE  \
# 7103                                Thangabali  1000.0
# 76                     Ceremonial Kitchen & Co  1000.0
# 13684                   Maharashtra Lunch Home   600.0
# 12432                          Quarter Canteen  1100.0
# 902    The Harbour Bay - SeaFood Kitchen & Bar  2400.0
# 884        Rajmanya- Seafood family restaurant   800.0
# 3379                                 Peco Peco   700.0
# 9953                        Pi Bar and Kitchen  1600.0
# 903                                Ferry Wharf  1500.0
# 915                   Monis Bar and Restaurant  1000.0
#
#                                          CUSINE_CATEGORY    REGION  \
# 7103      Seafood,South Indian,Mangalorean,Andhra,Kerala      Khar
# 76            Seafood,Maharashtrian,North Indian,Chinese     Thane
# 13684               Maharashtrian,Malwani,Konkan,Seafood  Kharghar
# 12432                       North Indian,Seafood,Chinese    Bandra
# 902                                    Seafood,Beverages    Bandra
# 884                         Maharashtrian,Konkan,Seafood     Vashi
# 3379                               Chinese,Seafood,Asian     Powai
# 9953   Continental,European,Italian,Seafood,Pizza,Des...   Andheri
# 903                                  Seafood,Mangalorean    Bandra
# 915    North Indian,Chinese,Continental,Seafood,Bever...     Thane
#
#          CUSINE TYPE                           TIMING RATING_TYPE  RATING  \
# 7103             Bar         12noon to 4pm,7pm to 3am   Excellent     4.7
# 76     Casual Dining                 1130am to 1130pm   Excellent     4.6
# 13684  Casual Dining      11am to 345pm,7pm to 1145pm   Excellent     4.6
# 12432  Casual Dining       12noon to 330pm,7pm to 1am   Excellent     4.5
# 902    Casual Dining                    12noon to 1am   Excellent     4.5
# 884    Casual Dining                     11am to 11pm   Excellent     4.5
# 3379            none    12noon to 330pm,7pm to 1230AM   Excellent     4.5
# 9953             Bar  12noon to 6pm,7pm to 12midnight   Excellent     4.5
# 903    Casual Dining      11am to 330pm,7pm to 1230AM   Very Good     4.4
# 915    Casual Dining    1130am to 330pm,6pm to 1130pm   Very Good     4.4
#
#         VOTES DAYS_OPEN
# 7103    564.0   Mon-Sun
# 76      350.0   Mon-Sun
# 13684   209.0   Mon-Sun
# 12432   573.0   Mon-Sun
# 902     100.0   Mon-Sun
# 884     178.0   Mon-Sun
# 3379    497.0   Mon-Sun
# 9953   2068.0   Mon-Sun
# 903     459.0   Mon-Sun
# 915     662.0   Mon-Sun

# %% [markdown]
# # Q4) Which is the best Food Truck in Mumbai?

# %%
foodtruck_df = zomato_df[zomato_df['CUSINE TYPE'] == 'Food Truck']
foodtruck_df.sort_values(by='RATING',ascending=False).head(2)
# Out:
#                    NAME  PRICE    CUSINE_CATEGORY   REGION CUSINE TYPE  \
# 262   Dumpling Delights  200.0              Momos  Matunga  Food Truck
# 1017    Street Food Co.  250.0  Fast Food,Chinese    Virar  Food Truck
#
#               TIMING RATING_TYPE  RATING  VOTES DAYS_OPEN
# 262   430pm to 930pm   Very Good     4.3  212.0   Mon-Sun
# 1017      6pm to 3am   Very Good     4.1  274.0   Mon-Sun

# %% [markdown]
# # Q5) Which places have the highest rated restaurant for each Cuisine Type in Mumbai?

# %%
# Assuming restaurants having rating above 4.5

highest_rated_df = zomato_df[zomato_df['RATING'] >= 4.5]
highest_rated_df
# Out:
#                              NAME   PRICE  \
# 0                         Hitchki  1200.0
# 6                  Persian Darbar  1300.0
# 7                         Tanatan  1500.0
# 9              Plum by Bent Chair  1800.0
# 10                  Angrezi Dhaba  1500.0
# ...                           ...     ...
# 14227  Zaika Crave - Club Aquaria  1300.0
# 14233                Cone Culture   250.0
# 15006                  Dessertino   300.0
# 15050                    Tick-eat   800.0
# 15055             Daftar Goregaon   750.0
#
#                                          CUSINE_CATEGORY       REGION  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...       Bandra
# 6                   Biryani,North Indian,Chinese,Mughlai        Marol
# 7                                          Modern Indian         Juhu
# 9                                                  Asian  Lower Parel
# 10                    North Indian,Chinese,Thai,European        Dadar
# ...                                                  ...          ...
# 14227          North Indian,Continental,Chinese,Desserts     Borivali
# 14233                                           European     Kharghar
# 15006                                 Desserts,Ice Cream    Kandivali
# 15050      North Indian,Italian,Chinese,Mexican,Lebanese       Mulund
# 15055               Pizza,Chinese,North Indian,Beverages     Goregaon
#
#           CUSINE TYPE                         TIMING RATING_TYPE  RATING  \
# 0       Casual Dining                12noon to 130am   Excellent     4.9
# 6       Casual Dining                    10am to 3am   Excellent     4.5
# 7       Casual Dining                12noon to 130am   Excellent     4.7
# 9       Casual Dining                  12noon to 1am   Excellent     4.7
# 10                Bar                  12noon to 1am   Excellent     4.5
# ...               ...                            ...         ...     ...
# 14227   Casual Dining    11am to 330pm,7pm to 1130pm   Excellent     4.5
# 14233   Casual Dining                         Closed   Excellent     4.6
# 15006  Dessert Parlor             11am to 12midnight   Excellent     4.8
# 15050   Casual Dining  1130am to 330pm,7pm to 1130pm   Excellent     4.5
# 15055   Casual Dining               12noon to 1130pm   Excellent     4.6
#
#         VOTES                   DAYS_OPEN
# 0      3529.0                     Mon-Sun
# 6      3058.0                     Mon-Sun
# 7      1842.0                     Mon-Sun
# 9      1876.0                     Mon-Sun
# 10     2092.0                     Mon-Sun
# ...       ...                         ...
# 14227  1302.0              Mon,Tue,Wed...
# 14233   492.0  Mon,12noon to 11pm(Tue-Sun
# 15006   184.0                     Mon-Sun
# 15050   754.0                     Mon-Sun
# 15055   388.0                     Mon-Sun
#
# [97 rows x 10 columns]

# %%
fig = px.histogram(highest_rated_df, x='REGION', color='CUSINE TYPE',
      title= 'No. of Best Restaurant for each Cuisine Type by Places').update_xaxes(categoryorder="total descending")
fig.show()

# %% [markdown]
# # Q6) What is the Avg Price Distibution of highest rated restaurant for each Cuisine Type in Mumbai?

# %%
highest_rated_price_df = highest_rated_df.groupby(by=['REGION', 'CUSINE TYPE'])['PRICE'].mean().reset_index()
highest_rated_price_df.head()
# Out:
#     REGION     CUSINE TYPE   PRICE
# 0  Andheri             Bar  1600.0
# 1  Andheri            Caf?   800.0
# 2  Andheri   Casual Dining  1212.5
# 3  Andheri  Dessert Parlor   300.0
# 4  Andheri          Lounge  1700.0

# %%
fig = px.scatter(highest_rated_price_df, x="REGION", y="PRICE", color="CUSINE TYPE", symbol="CUSINE TYPE",
 title=' Avg Price Distibution of High rated restaurant for each Cuisine Type').update_traces(marker_size=10)
fig.show()

# %% [markdown]
# # Q7) Which areas have a large number of Chinese Restaurant Market?#

# %%
chinese_df = zomato_df[zomato_df['CUSINE_CATEGORY'].str.contains('Chinese')]
chinese_df
# Out:
#                     NAME   PRICE  \
# 0                Hitchki  1200.0
# 2          Chin Chin Chu  1800.0
# 4              BKC  DIVE  1200.0
# 5       Flea Bazaar Caf?   800.0
# 6         Persian Darbar  1300.0
# ...                  ...     ...
# 15070      Lucknow Zaika   500.0
# 15071     Zuha's Kitchen   400.0
# 15074    Tirupati Balaji   500.0
# 15075  Hari Om Snack Bar   350.0
# 15078     Mandarin Panda   400.0
#
#                                          CUSINE_CATEGORY            REGION  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...            Bandra
# 2                                          Asian,Chinese              Juhu
# 4                       North Indian,Chinese,Continental            Bandra
# 5      American,Asian,Street Food,North Indian,Luckno...  Flea Bazaar Caf?
# 6                   Biryani,North Indian,Chinese,Mughlai             Marol
# ...                                                  ...               ...
# 15070                               North Indian,Chinese             Kurla
# 15071                       Chinese,North Indian,Mughlai    Mumbai Central
# 15074                     Chinese,Fast Food,North Indian           Andheri
# 15075                     Fast Food,South Indian,Chinese         Kandivali
# 15078                              Desserts,Chinese,Thai             Malad
#
#          CUSINE TYPE                           TIMING RATING_TYPE  RATING  \
# 0      Casual Dining                  12noon to 130am   Excellent     4.9
# 2      Casual Dining                    12noon to 1am   Very Good     4.2
# 4                Bar                    1130am to 1am   Very Good     4.4
# 5               Caf?                    12noon to 1am   Very Good     4.2
# 6      Casual Dining                      10am to 3am   Excellent     4.5
# ...              ...                              ...         ...     ...
# 15070    Quick Bites                    12noon to 2am     Average     2.6
# 15071    Quick Bites     12noon to 4pm,730pm to 430am     Average     3.3
# 15074  Casual Dining  8am to 11pm,12midnight to 115am        Good     3.5
# 15075    Quick Bites                    11am to 230am        Good     3.7
# 15078           none       12noon to 330pm,7pm to 1am        Good     3.7
#
#         VOTES DAYS_OPEN
# 0      3529.0   Mon-Sun
# 2       337.0   Mon-Sun
# 4      5995.0   Mon-Sun
# 5      2042.0   Mon-Sun
# 6      3058.0   Mon-Sun
# ...       ...       ...
# 15070    36.0   Mon-Sun
# 15071    13.0   Mon-Sun
# 15074   267.0   Mon-Sun
# 15075    64.0   Mon-Sun
# 15078   121.0   Mon-Sun
#
# [5118 rows x 10 columns]

# %%
chinese_rest_df = chinese_df.groupby(by='REGION').agg({'NAME' : 'count', 'PRICE' : 'mean'}).rename(columns= {'NAME':'COUNT OF RESTAURANTS'}).reset_index()
chinese_rest_df = chinese_rest_df.sort_values('COUNT OF RESTAURANTS', ascending=False).head(25)
chinese_rest_df.head()
# Out:
#            REGION  COUNT OF RESTAURANTS       PRICE
# 73          Thane                   371  590.983827
# 52      Mira Road                   224  553.348214
# 46          Malad                   185  601.891892
# 61  New Link Road                   176  603.125000
# 28       Goregaon                   163  548.773006

# %%
fig = px.bar(chinese_rest_df, x='REGION', y='COUNT OF RESTAURANTS', color='PRICE', title='No. of Chinese Restaurants by Region and Average Price')
fig.show()

# %% [markdown]
# # Q8) Is there a relation between Price and Rating by each Cuisine Type?

# %%
price_rating_df = zomato_df.groupby(['CUSINE TYPE', 'RATING'])['PRICE'].mean().reset_index()
price_rating_df
# Out:
#     CUSINE TYPE  RATING       PRICE
# 0        Bakery     2.7  400.000000
# 1        Bakery     2.8  285.714286
# 2        Bakery     2.9  328.571429
# 3        Bakery     3.0  300.000000
# 4        Bakery     3.1  369.117647
# ..          ...     ...         ...
# 278        none     4.3  683.333333
# 279        none     4.4  555.000000
# 280        none     4.5  420.000000
# 281        none     4.6  687.500000
# 282        none     4.7  350.000000
#
# [283 rows x 3 columns]

# %%
fig = px.line(price_rating_df, y="PRICE", x="RATING",color='CUSINE TYPE')
fig.show()

# %% [markdown]
# # Q9) Is there a relation between Region and Price?

# %%
region_price_df = zomato_df.groupby(['REGION'])['PRICE'].mean().reset_index()
region_price_df
# Out:
#         REGION       PRICE
# 0       Airoli  452.287582
# 1      Alibaug  665.000000
# 2    Ambernath  514.000000
# 3      Andheri  591.138614
# 4       Bandra  724.945946
# ..         ...         ...
# 77    Vikhroli  480.434783
# 78  Vile Parle  464.457831
# 79       Virar  452.027027
# 80      Wadala  427.500000
# 81       Worli  541.447368
#
# [82 rows x 2 columns]

# %%
fig = px.scatter(region_price_df, x="REGION", y="PRICE").update_traces(marker_size=8)
fig.show()

# %% [markdown]
# # Q10) Find the list of Affordable Restaurants?
# # The criteria for Affordable Restaurants would be:-
# # 1) Low Price 2) High Rated
# # First step will be to find the restaurants with average cost 1/4th the average cost of most expensive restaurant in our
# # dataframe.
# # Let me explain:-The most expensive restaurant has an average meal cost= 6000. We'll try to stay economical and only pick the
# # restaurants that are 1/4th of 6000.

# %%
max_price = zomato_df['PRICE'].max()
one_fourth_price = max_price/4
one_fourth_price
# Out:
# 1250.0

# %%
# Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restauran
aff_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE']]
aff_rest_df = aff_rest_df[aff_rest_df['PRICE'] <= 1250]
aff_rest_df.sort_values(by='PRICE', inplace=True)
aff_rest_df
# Out:
#                                                    NAME   PRICE  \
# 6136                                 Sanjog Wine N Dine     5.0
# 2924                                         Jab We Eat    50.0
# 9597                                          Ho5 Store    50.0
# 8821                                            Re Fuel   100.0
# 3337                                        Nawabi Paan   100.0
# ...                                                 ...     ...
# 493                                         Curry Twist  1200.0
# 0                                               Hitchki  1200.0
# 6044  Fabelle at The Chocolate Boutique - ITC Grand ...  1250.0
# 964                                        Bijoli Grill  1250.0
# 7300                               SamBar Pub & Kitchen  1250.0
#
#                                         CUSINE_CATEGORY     REGION  \
# 6136                               North Indian,Chinese      Thane
# 2924  South Indian,North Indian,Maharashtrian,Fast Food    Girgaum
# 9597                                          Fast Food    Matunga
# 8821                                             Juices      Dadar
# 3337                                               Paan  Kandivali
# ...                                                 ...        ...
# 493                North Indian,Continental,Asian,Salad   Sakinaka
# 0     Modern Indian,North Indian,Chinese,Momos,Birya...     Bandra
# 6044                                           Desserts      Parel
# 964                                             Bengali      Powai
# 7300              Finger Food,South Indian,North Indian       Khar
#
#          CUSINE TYPE
# 6136   Casual Dining
# 2924            none
# 9597            none
# 8821     Quick Bites
# 3337       Paan Shop
# ...              ...
# 493    Casual Dining
# 0      Casual Dining
# 6044  Dessert Parlor
# 964    Casual Dining
# 7300             Pub
#
# [10176 rows x 5 columns]

# %%
# Finding the highest rated list of restaurants

highrate_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE','RATING']]
highrate_rest_df = highrate_rest_df[highrate_rest_df['RATING'] >= 4.5]
highrate_rest_df.sort_values(by='PRICE', inplace=True)
highrate_rest_df
# Out:
#                                           NAME   PRICE  \
# 1502             Cake Centre-The Dessert Maker   150.0
# 763                     Curry And Combos Twist   200.0
# 807                               Moussestruck   200.0
# 14233                             Cone Culture   250.0
# 725                                  Belo Pops   300.0
# ...                                        ...     ...
# 5334                                Mia Cucina  2000.0
# 1785                             Global Fusion  2000.0
# 8886                      Drifters Tap Station  2000.0
# 12624                        House of Mandarin  2100.0
# 902    The Harbour Bay - SeaFood Kitchen & Bar  2400.0
#
#                                   CUSINE_CATEGORY             REGION  \
# 1502                                     Desserts  Mohammad Ali Road
# 763                          North Indian,Chinese            Andheri
# 807                                      Desserts      New Link Road
# 14233                                    European           Kharghar
# 725                  Ice Cream,Desserts,Beverages            Andheri
# ...                                           ...                ...
# 5334                                      Italian             Bandra
# 1785          Chinese,Japanese,Asian,North Indian              Worli
# 8886   North Indian,Continental,European,American             Bandra
# 12624                         Chinese,Sushi,Asian             Bandra
# 902                             Seafood,Beverages             Bandra
#
#           CUSINE TYPE  RATING
# 1502   Dessert Parlor     4.6
# 763       Quick Bites     4.5
# 807              none     4.5
# 14233   Casual Dining     4.6
# 725              none     4.5
# ...               ...     ...
# 5334    Casual Dining     4.5
# 1785      Fine Dining     4.6
# 8886    Casual Dining     4.5
# 12624   Casual Dining     4.5
# 902     Casual Dining     4.5
#
# [97 rows x 6 columns]

# %% [markdown]
# # Now, we'll merge the aff_rest_df with highrate_rest_df to obtain the intersection i.e the list of Affordable Restaurants !!

# %%
highrate_aff_df = pd.merge(aff_rest_df, highrate_rest_df, how='inner', on=['NAME', 'REGION'])
highrate_aff_df = highrate_aff_df[['NAME', 'PRICE_x', 'CUSINE_CATEGORY_x', 'REGION', 'CUSINE TYPE_x']]
highrate_aff_df.rename(columns={'NAME':'NAME', 'PRICE_x':'PRICE', 'CUSINE_CATEGORY_x':'CUSINE_CATEGORY',
 'REGION':'REGION', 'CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)

# %%
# Affordable Restaurants with low price and high rating

highrate_aff_df
# Out:
#                              NAME   PRICE  \
# 0   Cake Centre-The Dessert Maker   150.0
# 1          Curry And Combos Twist   200.0
# 2                    Moussestruck   200.0
# 3                    Cone Culture   250.0
# 4                     Smiley Pops   300.0
# ..                            ...     ...
# 60                        Invento  1200.0
# 61                 Culinary Tales  1200.0
# 62               The Joker Bistro  1200.0
# 63         Wild Dining Restaurant  1200.0
# 64                        Hitchki  1200.0
#
#                                       CUSINE_CATEGORY             REGION  \
# 0                                            Desserts  Mohammad Ali Road
# 1                                North Indian,Chinese            Andheri
# 2                                            Desserts      New Link Road
# 3                                            European           Kharghar
# 4               Desserts,Ice Cream,Beverages,Sandwich            Andheri
# ..                                                ...                ...
# 60     Chinese,Fast Food,North Indian,Italian,Mexican        Lower Parel
# 61   Chinese,European,Continental,Salad,Italian,Pizza      New Link Road
# 62                   North Indian,Chinese,Continental        CBD Belapur
# 63           North Indian,Continental,Mexican,Chinese            Andheri
# 64  Modern Indian,North Indian,Chinese,Momos,Birya...             Bandra
#
#        CUSINE TYPE
# 0   Dessert Parlor
# 1      Quick Bites
# 2             none
# 3    Casual Dining
# 4   Dessert Parlor
# ..             ...
# 60   Casual Dining
# 61   Casual Dining
# 62   Casual Dining
# 63   Casual Dining
# 64   Casual Dining
#
# [65 rows x 5 columns]

# %% [markdown]
# # Q10) Find the list of most Reliable Restaurants?
# # The criteria for most Reliable Restaurants would be:-
# # 1) Low Price 2) High Rated 3) Large No. of Votes
# # First step will be to find the restaurants with Votes greater than Mean of Votes

# %%
mean_votes = zomato_df['VOTES'].mean()
mean_votes
# Out:
# 177.30266780594323

# %%
# Finding list of restaurants that have Votes greater than and equal to Mean of Vote
mean_rest_df = zomato_df[['NAME', 'PRICE', 'CUSINE_CATEGORY', 'REGION', 'CUSINE TYPE', 'VOTES']]
mean_rest_df = mean_rest_df[mean_rest_df['VOTES'] > 177]
mean_rest_df.sort_values(by='VOTES', inplace=True)
mean_rest_df
# Out:
#                                NAME   PRICE  \
# 7827               Yaari Restaurant   350.0
# 12266                   Buddha Bowl  1000.0
# 2192                  Mumbai Darbar   850.0
# 2391      Jain Sweet & Farsan House   200.0
# 11210                    Soul Curry   800.0
# ...                             ...     ...
# 8538             Leopold Cafe & Bar  1600.0
# 1251                   Joey's Pizza   800.0
# 5336   Chili's American Grill & Bar  1400.0
# 3750                   Prithvi Cafe   700.0
# 8896                        Candies   700.0
#
#                                     CUSINE_CATEGORY       REGION  \
# 7827                    Chinese,Italian,Street Food    Bhayandar
# 12266                            Asian,Healthy Food       Bandra
# 2192                   North Indian,Chinese,Seafood  Lower Parel
# 2391         Street Food,Beverages,Fast Food,Mithai     Goregaon
# 11210  Chinese,North Indian,Malwani,Mughlai,Biryani      Bhandup
# ...                                             ...          ...
# 8538               American,Chinese,Mughlai,Italian       Colaba
# 1251                                          Pizza        Malad
# 5336                American,Mexican,Burger,Tex-Mex        Powai
# 3750                                 Cafe,Fast Food         Juhu
# 8896             Cafe,Italian,North Indian,Desserts       Bandra
#
#          CUSINE TYPE    VOTES
# 7827     Quick Bites    178.0
# 12266           none    178.0
# 2192   Casual Dining    178.0
# 2391     Quick Bites    178.0
# 11210  Casual Dining    178.0
# ...              ...      ...
# 8538   Casual Dining   7327.0
# 1251     Quick Bites   7350.0
# 5336   Casual Dining   7377.0
# 3750            Caf?   8000.0
# 8896            Caf?  10217.0
#
# [2343 rows x 6 columns]

# %% [markdown]
# # These are the most reliable, highest rated and affordable restaurants:-
# # We obtain this dataframe by simply taking the intersection of highrate_aff_df & mean_rest_df
# # This dataframe obtained below shows the restaurants whose:
# # Cost is below 1250
# # Rating is above 4.5
# # Votes are above 177

# %%
reliable_rest_df = pd.merge(mean_rest_df, highrate_aff_df, how='inner', on=['NAME', 'REGION'])
reliable_rest_df = reliable_rest_df[['NAME', 'PRICE_x', 'CUSINE_CATEGORY_x', 'REGION', 'CUSINE TYPE_x']]
reliable_rest_df.rename(columns={'NAME':'NAME', 'PRICE_x':'PRICE', 'CUSINE_CATEGORY_x':'CUSINE_CATEGORY',
 'REGION':'REGION', 'CUSINE TYPE_x':'CUSINE TYPE'},inplace=True)

# %%
reliable_rest_df
# Out:
#                                    NAME   PRICE  \
# 0   Rajmanya- Seafood family restaurant   800.0
# 1                        Fresh Food Co.   500.0
# 2                            Dessertino   300.0
# 3                               Invento  1200.0
# 4                Maharashtra Lunch Home   600.0
# 5                              Regano's   600.0
# 6                       Big Bang Cuurry   350.0
# 7                           Sandy's Den  1000.0
# 8                     Angrezi Patiyalaa  1200.0
# 9                                 Maezo  1000.0
# 10                         Tossin Pizza   900.0
# 11                    Little West Pizza   600.0
# 12              Ceremonial Kitchen & Co  1000.0
# 13                         Moussestruck   200.0
# 14                      Daftar Goregaon   750.0
# 15          Poetry By Love & Cheesecake  1000.0
# 16                         Makhan Singh   800.0
# 17                     The Joker Bistro  1200.0
# 18                         Cone Culture   250.0
# 19                            Peco Peco   700.0
# 20           Shuruwat- Veg Food Journey   600.0
# 21                Justice Cafe and Dine   800.0
# 22                           Thangabali  1000.0
# 23                       Harsh's Bistro   800.0
# 24                      Quarter Canteen  1100.0
# 25                       Culinary Tales  1200.0
# 26                          Dum & Curry   700.0
# 27                        Curry Culture   800.0
# 28                            Belo Pops   300.0
# 29                             Tick-eat   800.0
# 30              Coppetto Artisan Gelato   350.0
# 31        Zaika Restaurant & Party Hall  1000.0
# 32                      Shaollin Temple  1000.0
# 33                       Spice Republic  1200.0
# 34                  Aquafire Restaurant  1100.0
# 35                             Rajdhani   950.0
# 36               Wild Dining Restaurant  1200.0
# 37                          Family Tree   800.0
# 38                     Bombay Salad Co.   900.0
# 39                           Cafe Monza  1000.0
# 40                              Hitchki  1200.0
# 41                                Vedge  1000.0
# 42                         Joey's Pizza   800.0
#
#                                       CUSINE_CATEGORY         REGION  \
# 0                        Maharashtrian,Konkan,Seafood          Vashi
# 1   Continental,Healthy Food,Salad,Beverages,Desse...      Santacruz
# 2                                  Desserts,Ice Cream      Kandivali
# 3      Chinese,Fast Food,North Indian,Italian,Mexican    Lower Parel
# 4                Maharashtrian,Malwani,Konkan,Seafood       Kharghar
# 5              Continental,Fast Food,Italian,Desserts          Malad
# 6                          North Indian,Biryani,Rolls  New Link Road
# 7                                  Fast Food,Bar Food        Chembur
# 8   North Indian,Finger Food,American,Mexican,Chinese        Andheri
# 9                                       Modern Indian          Thane
# 10                            Pizza,Italian,Fast Food        Chembur
# 11                                              Pizza       Borivali
# 12         Seafood,Maharashtrian,North Indian,Chinese          Thane
# 13                                           Desserts  New Link Road
# 14               Pizza,Chinese,North Indian,Beverages       Goregaon
# 15                                      Cafe,Desserts           Juhu
# 16                       North Indian,Chinese,Biryani          Powai
# 17                   North Indian,Chinese,Continental    CBD Belapur
# 18                                           European       Kharghar
# 19                              Chinese,Seafood,Asian          Powai
# 20  Continental,Tea,South Indian,Fast Food,Pizza,N...      Ghatkopar
# 21  Cafe,Chinese,Italian,Continental,North Indian,...          Thane
# 22     Seafood,South Indian,Mangalorean,Andhra,Kerala           Khar
# 23                                Chinese,Continental          Malad
# 24                       North Indian,Seafood,Chinese         Bandra
# 25   Chinese,European,Continental,Salad,Italian,Pizza  New Link Road
# 26                       Mughlai,North Indian,Chinese          Powai
# 27   North Indian,Biryani,Chinese,Kebab,Mughlai,Asian          Powai
# 28                       Ice Cream,Desserts,Beverages        Andheri
# 29      North Indian,Italian,Chinese,Mexican,Lebanese         Mulund
# 30                                 Ice Cream,Desserts         Bandra
# 31                     North Indian,Chinese,Beverages      Bhayandar
# 32                                       Chinese,Thai    CBD Belapur
# 33  Cafe,Continental,Mediterranean,Mexican,Italian...       Borivali
# 34           North Indian,Continental,Chinese,Italian     Vile Parle
# 35                   Gujarati,Rajasthani,North Indian      Ghatkopar
# 36           North Indian,Continental,Mexican,Chinese        Andheri
# 37         Italian,Mexican,North Indian,Chinese,Salad          Thane
# 38                          Salad,Healthy Food,Juices         Bandra
# 39                     Italian,American,Salad,Mexican       Kharghar
# 40  Modern Indian,North Indian,Chinese,Momos,Birya...         Bandra
# 41    Thai,Chinese,North Indian,Mexican,Italian,Asian  New Link Road
# 42                                              Pizza          Malad
#
#        CUSINE TYPE
# 0    Casual Dining
# 1             none
# 2   Dessert Parlor
# 3    Casual Dining
# 4    Casual Dining
# 5    Casual Dining
# 6             none
# 7    Casual Dining
# 8    Casual Dining
# 9    Casual Dining
# 10   Casual Dining
# 11     Quick Bites
# 12   Casual Dining
# 13            none
# 14   Casual Dining
# 15            Caf?
# 16            none
# 17   Casual Dining
# 18   Casual Dining
# 19            none
# 20   Casual Dining
# 21            Caf?
# 22             Bar
# 23   Casual Dining
# 24   Casual Dining
# 25   Casual Dining
# 26     Quick Bites
# 27            none
# 28            none
# 29   Casual Dining
# 30  Dessert Parlor
# 31   Casual Dining
# 32   Casual Dining
# 33            Caf?
# 34   Casual Dining
# 35   Casual Dining
# 36   Casual Dining
# 37   Casual Dining
# 38   Casual Dining
# 39   Casual Dining
# 40   Casual Dining
# 41   Casual Dining
# 42     Quick Bites
